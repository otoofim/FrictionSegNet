# %%
import scipy.io
import scipy.stats
import matplotlib.pyplot as plt
import re
import os
from IPython.display import Image 
import cv2
from tempfile import TemporaryFile
from scipy import stats
from torchvision import transforms
import pandas as pd
import shutil
import datetime
import glob
from scipy import integrate
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader
from PIL import ImageFile, Image
import sys
sys.path.insert(1, '../architecture')
sys.path.insert(2, '../dataLoaders')
from ProUNet import *
import torchvision.models as models
from MapillaryDataLoader import *
from volvoDataLoader_onFly import *
from VolvoDataLoader import *
from tqdm import tqdm
from torchsummary import summary
from torchvision import models
from torchsummary import summary
#from MapRSCD import *
# %matplotlib inline
# Out:
# 2023-11-27 16:48:57.545123: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
args = {
    "mode":"train",
    "input_img_dim":(256,256),
    "mapillaryRootPath":'../../../datasets/augmented_mapillary',
    "cityscapesRootPath":'../../../datasets/augmented_cityscapes',
    "RSCDRootPath":'../../../datasets/RSCD',
    "volvoRootPath":"../../../datasets/VolvoAnnotatedImages/rawDataset/images",
    "reducedCategories":True
}

dataloader = volvo_onFly(**args)

# %%
device = torch.device('cuda')
model = ProUNet(gecoConfig = {"enable":False}, device = device, num_classes = dataloader.get_num_classes(), LatentVarSize = 6, beta = 3, training = True, num_samples = 16).to(device)

# %%
# summary(model, [(3, 256, 226), (8, 256, 226), (1, 256, 226)])

# %%
# print(model)

# %%
for name, param in model.named_parameters():
    print(f"Parameter: {name}, Shape: {param.shape}")
# Out:
# Parameter: prior.DownConvBlock1.firstLayer.weight, Shape: torch.Size([128, 3, 3, 3])
# Parameter: prior.DownConvBlock1.firstLayer.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.DownConvBlock1.layers.0.conv1.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.bn1.weight, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.bn1.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.DownConvBlock1.layers.0.conv2.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.bn2.weight, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.0.bn2.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.DownConvBlock1.layers.1.conv1.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.bn1.weight, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.bn1.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.DownConvBlock1.layers.1.conv2.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.bn2.weight, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock1.layers.1.bn2.bias, Shape: torch.Size([128])
# Parameter: prior.DownConvBlock2.firstLayer.weight, Shape: torch.Size([256, 128, 3, 3])
# Parameter: prior.DownConvBlock2.firstLayer.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock2.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock2.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock2.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock2.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock2.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock3.firstLayer.weight, Shape: torch.Size([512, 256, 3, 3])
# Parameter: prior.DownConvBlock3.firstLayer.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.DownConvBlock3.layers.0.conv1.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.bn1.weight, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.bn1.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.DownConvBlock3.layers.0.conv2.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.bn2.weight, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.0.bn2.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.DownConvBlock3.layers.1.conv1.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.bn1.weight, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.bn1.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.DownConvBlock3.layers.1.conv2.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.bn2.weight, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock3.layers.1.bn2.bias, Shape: torch.Size([512])
# Parameter: prior.DownConvBlock4.firstLayer.weight, Shape: torch.Size([256, 512, 3, 3])
# Parameter: prior.DownConvBlock4.firstLayer.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock4.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock4.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock4.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.DownConvBlock4.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.DownConvBlock4.distLayer.weight, Shape: torch.Size([12, 256, 1, 1])
# Parameter: prior.DownConvBlock4.distLayer.bias, Shape: torch.Size([12])
# Parameter: prior.UpConvBlock1.firstLayer.0.weight, Shape: torch.Size([256, 512, 4, 4])
# Parameter: prior.UpConvBlock1.firstLayer.0.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.UpConvBlock1.layers.0.conv1.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.bn1.weight, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.bn1.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.UpConvBlock1.layers.0.conv2.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.bn2.weight, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.0.bn2.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.UpConvBlock1.layers.1.conv1.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.bn1.weight, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.bn1.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: prior.UpConvBlock1.layers.1.conv2.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.bn2.weight, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock1.layers.1.bn2.bias, Shape: torch.Size([512])
# Parameter: prior.UpConvBlock2.firstLayer.0.weight, Shape: torch.Size([1030, 256, 4, 4])
# Parameter: prior.UpConvBlock2.firstLayer.0.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.UpConvBlock2.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.UpConvBlock2.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.UpConvBlock2.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: prior.UpConvBlock2.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: prior.UpConvBlock2.distLayer.0.weight, Shape: torch.Size([12, 256, 1, 1])
# Parameter: prior.UpConvBlock2.distLayer.0.bias, Shape: torch.Size([12])
# Parameter: prior.UpConvBlock3.firstLayer.0.weight, Shape: torch.Size([518, 128, 4, 4])
# Parameter: prior.UpConvBlock3.firstLayer.0.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.UpConvBlock3.layers.0.conv1.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.bn1.weight, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.bn1.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.UpConvBlock3.layers.0.conv2.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.bn2.weight, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.0.bn2.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.UpConvBlock3.layers.1.conv1.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.bn1.weight, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.bn1.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: prior.UpConvBlock3.layers.1.conv2.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.bn2.weight, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.layers.1.bn2.bias, Shape: torch.Size([128])
# Parameter: prior.UpConvBlock3.distLayer.0.weight, Shape: torch.Size([12, 128, 1, 1])
# Parameter: prior.UpConvBlock3.distLayer.0.bias, Shape: torch.Size([12])
# Parameter: prior.UpConvBlock4.firstLayer.0.weight, Shape: torch.Size([262, 8, 4, 4])
# Parameter: prior.UpConvBlock4.firstLayer.0.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.conv1.weight, Shape: torch.Size([8, 8, 3, 3])
# Parameter: prior.UpConvBlock4.layers.0.conv1.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.bn1.weight, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.bn1.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.conv2.weight, Shape: torch.Size([8, 8, 3, 3])
# Parameter: prior.UpConvBlock4.layers.0.conv2.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.bn2.weight, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.0.bn2.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.conv1.weight, Shape: torch.Size([8, 8, 3, 3])
# Parameter: prior.UpConvBlock4.layers.1.conv1.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.bn1.weight, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.bn1.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.conv2.weight, Shape: torch.Size([8, 8, 3, 3])
# Parameter: prior.UpConvBlock4.layers.1.conv2.bias, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.bn2.weight, Shape: torch.Size([8])
# Parameter: prior.UpConvBlock4.layers.1.bn2.bias, Shape: torch.Size([8])
# Parameter: prior.regressionLayer.firstLayer.0.weight, Shape: torch.Size([262, 1, 4, 4])
# Parameter: prior.regressionLayer.firstLayer.0.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.conv1.weight, Shape: torch.Size([1, 1, 3, 3])
# Parameter: prior.regressionLayer.layers.0.conv1.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.bn1.weight, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.bn1.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.conv2.weight, Shape: torch.Size([1, 1, 3, 3])
# Parameter: prior.regressionLayer.layers.0.conv2.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.bn2.weight, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.0.bn2.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.conv1.weight, Shape: torch.Size([1, 1, 3, 3])
# Parameter: prior.regressionLayer.layers.1.conv1.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.bn1.weight, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.bn1.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.conv2.weight, Shape: torch.Size([1, 1, 3, 3])
# Parameter: prior.regressionLayer.layers.1.conv2.bias, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.bn2.weight, Shape: torch.Size([1])
# Parameter: prior.regressionLayer.layers.1.bn2.bias, Shape: torch.Size([1])
# Parameter: prior.crf.smoothness_weight, Shape: torch.Size([])
# Parameter: prior.crf.inv_smoothness_theta, Shape: torch.Size([2])
# Parameter: posterior.DownConvBlock1.firstLayer.weight, Shape: torch.Size([128, 12, 3, 3])
# Parameter: posterior.DownConvBlock1.firstLayer.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.DownConvBlock1.layers.0.conv1.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.bn1.weight, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.bn1.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.DownConvBlock1.layers.0.conv2.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.bn2.weight, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.0.bn2.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.DownConvBlock1.layers.1.conv1.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.bn1.weight, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.bn1.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.DownConvBlock1.layers.1.conv2.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.bn2.weight, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock1.layers.1.bn2.bias, Shape: torch.Size([128])
# Parameter: posterior.DownConvBlock2.firstLayer.weight, Shape: torch.Size([256, 128, 3, 3])
# Parameter: posterior.DownConvBlock2.firstLayer.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock2.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock2.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock2.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock2.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock2.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock3.firstLayer.weight, Shape: torch.Size([512, 256, 3, 3])
# Parameter: posterior.DownConvBlock3.firstLayer.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.DownConvBlock3.layers.0.conv1.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.bn1.weight, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.bn1.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.DownConvBlock3.layers.0.conv2.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.bn2.weight, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.0.bn2.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.DownConvBlock3.layers.1.conv1.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.bn1.weight, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.bn1.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.DownConvBlock3.layers.1.conv2.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.bn2.weight, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock3.layers.1.bn2.bias, Shape: torch.Size([512])
# Parameter: posterior.DownConvBlock4.firstLayer.weight, Shape: torch.Size([256, 512, 3, 3])
# Parameter: posterior.DownConvBlock4.firstLayer.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock4.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock4.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock4.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.DownConvBlock4.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.DownConvBlock4.distLayer.weight, Shape: torch.Size([12, 256, 1, 1])
# Parameter: posterior.DownConvBlock4.distLayer.bias, Shape: torch.Size([12])
# Parameter: posterior.UpConvBlock1.firstLayer.0.weight, Shape: torch.Size([256, 512, 4, 4])
# Parameter: posterior.UpConvBlock1.firstLayer.0.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.UpConvBlock1.layers.0.conv1.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.bn1.weight, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.bn1.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.UpConvBlock1.layers.0.conv2.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.bn2.weight, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.0.bn2.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.conv1.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.UpConvBlock1.layers.1.conv1.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.bn1.weight, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.bn1.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.conv2.weight, Shape: torch.Size([512, 512, 3, 3])
# Parameter: posterior.UpConvBlock1.layers.1.conv2.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.bn2.weight, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock1.layers.1.bn2.bias, Shape: torch.Size([512])
# Parameter: posterior.UpConvBlock2.firstLayer.0.weight, Shape: torch.Size([1030, 256, 4, 4])
# Parameter: posterior.UpConvBlock2.firstLayer.0.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.UpConvBlock2.layers.0.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.UpConvBlock2.layers.0.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.0.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.conv1.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.UpConvBlock2.layers.1.conv1.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.bn1.weight, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.bn1.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.conv2.weight, Shape: torch.Size([256, 256, 3, 3])
# Parameter: posterior.UpConvBlock2.layers.1.conv2.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.bn2.weight, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.layers.1.bn2.bias, Shape: torch.Size([256])
# Parameter: posterior.UpConvBlock2.distLayer.0.weight, Shape: torch.Size([12, 256, 1, 1])
# Parameter: posterior.UpConvBlock2.distLayer.0.bias, Shape: torch.Size([12])
# Parameter: posterior.UpConvBlock3.firstLayer.0.weight, Shape: torch.Size([518, 128, 4, 4])
# Parameter: posterior.UpConvBlock3.firstLayer.0.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.UpConvBlock3.layers.0.conv1.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.bn1.weight, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.bn1.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.UpConvBlock3.layers.0.conv2.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.bn2.weight, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.0.bn2.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.conv1.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.UpConvBlock3.layers.1.conv1.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.bn1.weight, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.bn1.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.conv2.weight, Shape: torch.Size([128, 128, 3, 3])
# Parameter: posterior.UpConvBlock3.layers.1.conv2.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.bn2.weight, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.layers.1.bn2.bias, Shape: torch.Size([128])
# Parameter: posterior.UpConvBlock3.distLayer.0.weight, Shape: torch.Size([12, 128, 1, 1])
# Parameter: posterior.UpConvBlock3.distLayer.0.bias, Shape: torch.Size([12])
